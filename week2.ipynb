# %%
  #1 Write a program that asks the user for their name, age, and marks, then prints them in a formatted way.
name = input("Enter your name: ")
age = int(input("Enter your Age: "))
marks = float(input("Enter your Marks: "))

print("Name: ",name)
print("Age: ",age)
print("Marks: ",marks)
# Out:
# Enter your name: shamim sheikh
# Enter your Age: 21
# Enter your Marks: 99
# Name:  shamim sheikh
# Age:  21
# Marks:  99.0

# %%
#2 Create three variables: one int, one float, and one string. Print their types.
x = 50
y = 99.9
z = "HELLO"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
#3 Write a program that takes two numbers as input, adds them, and prints the result.

x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
add = x+y
print ("Result: ",add)
# Out:
# Enter first number: 23
# Enter second number: 20
# Result:  43

# %%
#4 Write a program to calculate the area of a rectangle with proper comments.

length = int(input("Enter length of rectangle: ")) # take length as input from user
breadth = int(input("Enter breadth of rectangele: ")) # take breadth as input from user
area = length*breadth                       #Calculating the area of rectangle
print("Area of Rectangle:",area)       #Print Area of Rectangle
# Out:
# Enter length of rectangle: 20
# Enter breadth of rectangele: 10
# Area of Rectangle: 200

# %% [markdown]
# #5
# Python: Dynamic Typing
#
# Variable types are decided at runtime, not in advance.
#
# You don’t need to declare the type of a variable.
#
# A variable can change type during execution.
#
# for example:
#
# x = 5        # x is an int
#
# x = "hello"  # now x is a str
#
# C / Java: Static Typing
#
# Variable types are defined at compile time.
#
# You must declare the type of every variable.
#
# A variable cannot change type once declared.
#
# for example:-
#
# int x = 5;       // x is an int
#
# x = "hello";     // Error: Type mismatch
