# %%
#1 Write and run a Python program that prints "Hello, welcome to AlgoMind Academy!".
print("Hello, Welcome to Algomind Academy")
# Out:
# Hello, Welcome to Algomind Academy

# %% [markdown]
# #2 Explain in your own words how Python code is executed
# The execution of the Python program involves 2 Steps:
#
# 1.Compilation:-The program is converted into byte code.
#
# 2.Interpreter:-The next step involves converting the byte code (.pyc file) into machine code.
#
# Python reads the code line by line and executes it.
#
# python follow a systematic code syantax.

# %%
#3
print("hello"
# Out:
#   File "/tmp/ipython-input-4227803888.py", line 1
#     print("hello"
#                  ^
# SyntaxError: incomplete input

# %%
#4
#Install Python and show (or explain) how you ran your first program.
Step 1: Install Python

 Windows

Go to the official Python website

Click Download Python 3.x.x (latest version).

Run the downloaded installer.

IMPORTANT: Check the box “Add Python to PATH”.

Click Install Now and finish the installation.

Step2:-Run a Python Script File

Open a text editor (like Notepad or VS Code).

Write this code:

print("Hello, world!")


Save the file as hello.py.

Open a terminal or command prompt.

Navigate to the folder where the file is saved.

# %%
#5
#Write a program to print your name, age, and city.
name="Shamim Sheikh"
age="21"
city="Indore"
print(name)
print(age)
print(city)
# Out:
# Shamim Sheikh
# 21
# Indore
